# %% [markdown]
# ## #BuildWithAI - Armor Team

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import re
warnings.filterwarnings('ignore')
# %matplotlib inline

# Set up the chosen style format
plt.style.use('fivethirtyeight')
# %matplotlib inline

# Increase default figure and font sizes for easier viewing.
plt.rcParams['figure.figsize'] = (12, 8)
plt.rcParams['font.size'] = 14
sns.set_context('notebook')

# %%
# load dataset
data = pd.read_csv("2020-04-30_Coronavirus_Tweets.CSV")

# %% [markdown]
# ### Cleaning and Extracting

# %%
# Remove links from tweets
data['tweet'] = data['text'].apply(lambda x: re.split('https:\/\/.*', str(x))[0])

# %%
# Extract the most 5000 likeable tweets
data_top = data.nlargest(5000,'favourites_count')

# %%
data_top
# Out:
#                   status_id             user_id            created_at  \
# 462057  1250876607239249920          1245214176  2020-04-16T19:59:57Z
# 468237  1250879975953182721          1245214176  2020-04-16T20:13:21Z
# 294824  1250798677796544513  783028986205069312  2020-04-16T14:50:18Z
# 284413  1250793907987705856            94346808  2020-04-16T14:31:20Z
# 178246  1250737886376398848  804366366522376193  2020-04-16T10:48:44Z
# ...                     ...                 ...                   ...
# 47293   1250627684222119936            38486830  2020-04-16T03:30:50Z
# 34674   1250611780814061569            29235171  2020-04-16T02:27:38Z
# 116324  1250696890556903424  903270351064285184  2020-04-16T08:05:50Z
# 55992   1250639027038031873  903270351064285184  2020-04-16T04:15:54Z
# 77299   1250665076161499136          1295911188  2020-04-16T05:59:25Z
#
#             screen_name                                               text  \
# 462057    ChelseaAMusic  Ever since the #COVID19 epidemic began i think...
# 468237    ChelseaAMusic  Horrible what @FashionNova is doing to people ...
# 294824  MiguelCalabria3  "Las tormentas hacen apreciar\n lo “extraordin...
# 284413       GokhanAkar  Güzel Olmuş...\n 😍😍😍\n"Ruh Eşi"\nhttps://t.co/...
# 178246      SueRMichael  This is a wonderful story of surviving #COVID1...
# ...                 ...                                                ...
# 47293    VividConfusion  @preferspuppies @WeTalkSportz @cnnbrk That's t...
# 34674           daahmom  @dawg_lb It was #CCP &amp; #WHO telling us tha...
# 116324     AapActive123  How well is Delhi prepared to tackle  #covid19...
# 55992      AapActive123  Breaking: Over the past 24 hours, the U.S. rep...
# 77299       MOVIESTVMAD  So let's just pretend that #Covid_19 isn't a 8...
#
#                      source  reply_to_status_id  reply_to_user_id  \
# 462057  Twitter for Android                 NaN               NaN
# 468237  Twitter for Android                 NaN               NaN
# 294824  Twitter for Android                 NaN               NaN
# 284413  Twitter for Android                 NaN               NaN
# 178246  Twitter for Android                 NaN               NaN
# ...                     ...                 ...               ...
# 47293   Twitter for Android        1.250625e+18      3.230339e+07
# 34674    Twitter for iPhone        1.250576e+18      7.381535e+17
# 116324  Twitter for Android                 NaN               NaN
# 55992   Twitter for Android                 NaN               NaN
# 77299   Twitter for Android                 NaN               NaN
#
#        reply_to_screen_name  is_quote  ...  country_code  place_full_name  \
# 462057                  NaN     False  ...           NaN              NaN
# 468237                  NaN     False  ...           NaN              NaN
# 294824                  NaN     False  ...           NaN              NaN
# 284413                  NaN     False  ...           NaN              NaN
# 178246                  NaN      True  ...           NaN              NaN
# ...                     ...       ...  ...           ...              ...
# 47293        preferspuppies     False  ...           NaN              NaN
# 34674               dawg_lb     False  ...           NaN              NaN
# 116324                  NaN     False  ...           NaN              NaN
# 55992                   NaN     False  ...           NaN              NaN
# 77299                   NaN     False  ...           NaN              NaN
#
#         place_type followers_count friends_count account_lang  \
# 462057         NaN           22629         22631          NaN
# 468237         NaN           22629         22631          NaN
# 294824         NaN            9094           243          NaN
# 284413         NaN           73120         20439          NaN
# 178246         NaN            1563          1081          NaN
# ...            ...             ...           ...          ...
# 47293          NaN             725          1064          NaN
# 34674          NaN           46045         46060          NaN
# 116324         NaN            1476           179          NaN
# 55992          NaN            1476           179          NaN
# 77299          NaN            1490          3595          NaN
#
#           account_created_at  verified  lang  \
# 462057  2013-03-06T04:11:45Z     False    en
# 468237  2013-03-06T04:11:45Z     False    en
# 294824  2016-10-03T19:40:33Z     False    es
# 284413  2009-12-03T15:08:58Z      True    tr
# 178246  2016-12-01T16:47:41Z     False    en
# ...                      ...       ...   ...
# 47293   2009-05-07T18:32:14Z     False    en
# 34674   2009-04-06T16:34:07Z     False    en
# 116324  2017-08-31T14:56:48Z     False    en
# 55992   2017-08-31T14:56:48Z     False    en
# 77299   2013-03-24T16:59:44Z     False    en
#
#                                                     tweet
# 462057  Ever since the #COVID19 epidemic began i think...
# 468237  Horrible what @FashionNova is doing to people ...
# 294824  "Las tormentas hacen apreciar\n lo “extraordin...
# 284413                  Güzel Olmuş...\n 😍😍😍\n"Ruh Eşi"\n
# 178246  This is a wonderful story of surviving #COVID1...
# ...                                                   ...
# 47293   @preferspuppies @WeTalkSportz @cnnbrk That's t...
# 34674   @dawg_lb It was #CCP &amp; #WHO telling us tha...
# 116324  How well is Delhi prepared to tackle  #covid19...
# 55992   Breaking: Over the past 24 hours, the U.S. rep...
# 77299   So let's just pretend that #Covid_19 isn't a 8...
#
# [5000 rows x 23 columns]

# %% [markdown]
# ### Translating non-English Tweets

# %%
# Translation and returning to data_top
# !pip install googletrans

# import the library
import googletrans
from googletrans import Translator
# Out:
# Requirement already satisfied: googletrans in /Users/arwa/opt/anaconda3/lib/python3.7/site-packages (3.0.0)
# Requirement already satisfied: httpx==0.13.3 in /Users/arwa/opt/anaconda3/lib/python3.7/site-packages (from googletrans) (0.13.3)
# Requirement already satisfied: hstspreload in /Users/arwa/opt/anaconda3/lib/python3.7/site-packages (from httpx==0.13.3->googletrans) (2020.7.22)
# Requirement already satisfied: certifi in /Users/arwa/opt/anaconda3/lib/python3.7/site-packages (from httpx==0.13.3->googletrans) (2019.11.28)
# Requirement already satisfied: sniffio in /Users/arwa/opt/anaconda3/lib/python3.7/site-packages (from httpx==0.13.3->googletrans) (1.1.0)
# Requirement already satisfied: rfc3986<2,>=1.3 in /Users/arwa/opt/anaconda3/lib/python3.7/site-packages (from httpx==0.13.3->googletrans) (1.4.0)
# Requirement already satisfied: idna==2.* in /Users/arwa/opt/anaconda3/lib/python3.7/site-packages (from httpx==0.13.3->googletrans) (2.8)
# Requirement already satisfied: chardet==3.* in /Users/arwa/opt/anaconda3/lib/python3.7/site-packages (from httpx==0.13.3->googletrans) (3.0.4)
# Requirement already satisfied: httpcore==0.9.* in /Users/arwa/opt/anaconda3/lib/python3.7/site-packages (from httpx==0.13.3->googletrans) (0.9.1)
# Requirement already satisfied: h2==3.* in /Users/arwa/opt/anaconda3/lib/python3.7/site-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans) (3.2.0)
# Requirement already satisfied: h11<0.10,>=0.8 in /Users/arwa/opt/anaconda3/lib/python3.7/site-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans) (0.9.0)
# Requirement already satisfied: hpack<4,>=3.0 in /Users/arwa/opt/anaconda3/lib/python3.7/site-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans) (3.0.0)
# Requirement already satisfied: hyperframe<6,>=5.2.0 in /Users/arwa/opt/anaconda3/lib/python3.7/site-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans) (5.2.0)

# %%
data_translate = data_top[data_top["lang"] != "en"]
data_eng = data_top[data_top["lang"] == "en"]

# %%
translator = Translator()
data_translate['tweet_en'] = data_translate['tweet'].apply(translator.translate, src='auto', dest='en').apply(getattr, args=('text',))

# %%
data_translate = data_translate.drop(['tweet'], axis=1)
data_translate = data_translate.rename(columns={'tweet_en': 'tweet'})

# %%
data_merge = pd.concat([data_translate, data_eng], ignore_index=True)

# %%
data_merge
# Out:
#                 status_id             user_id            created_at  \
# 0     1250798677796544513  783028986205069312  2020-04-16T14:50:18Z
# 1     1250793907987705856            94346808  2020-04-16T14:31:20Z
# 2     1250802390946676736          1341462944  2020-04-16T15:05:03Z
# 3     1250878232909529094          1341462944  2020-04-16T20:06:25Z
# 4     1250888059756908544          1341462944  2020-04-16T20:45:28Z
# ...                   ...                 ...                   ...
# 4995  1250627684222119936            38486830  2020-04-16T03:30:50Z
# 4996  1250611780814061569            29235171  2020-04-16T02:27:38Z
# 4997  1250696890556903424  903270351064285184  2020-04-16T08:05:50Z
# 4998  1250639027038031873  903270351064285184  2020-04-16T04:15:54Z
# 4999  1250665076161499136          1295911188  2020-04-16T05:59:25Z
#
#           screen_name                                               text  \
# 0     MiguelCalabria3  "Las tormentas hacen apreciar\n lo “extraordin...
# 1          GokhanAkar  Güzel Olmuş...\n 😍😍😍\n"Ruh Eşi"\nhttps://t.co/...
# 2          paoloigna1  In un tweet precedente ho scritto che Guido Ol...
# 3          paoloigna1  a tutta velocità #innovazione #3D #Ferrari #co...
# 4          paoloigna1  Sento il dibattito a #Piazzapulita e sembra ch...
# ...               ...                                                ...
# 4995   VividConfusion  @preferspuppies @WeTalkSportz @cnnbrk That's t...
# 4996          daahmom  @dawg_lb It was #CCP &amp; #WHO telling us tha...
# 4997     AapActive123  How well is Delhi prepared to tackle  #covid19...
# 4998     AapActive123  Breaking: Over the past 24 hours, the U.S. rep...
# 4999      MOVIESTVMAD  So let's just pretend that #Covid_19 isn't a 8...
#
#                    source  reply_to_status_id  reply_to_user_id  \
# 0     Twitter for Android                 NaN               NaN
# 1     Twitter for Android                 NaN               NaN
# 2      Twitter Web Client                 NaN               NaN
# 3         Twitter Web App                 NaN               NaN
# 4      Twitter Web Client                 NaN               NaN
# ...                   ...                 ...               ...
# 4995  Twitter for Android        1.250625e+18      3.230339e+07
# 4996   Twitter for iPhone        1.250576e+18      7.381535e+17
# 4997  Twitter for Android                 NaN               NaN
# 4998  Twitter for Android                 NaN               NaN
# 4999  Twitter for Android                 NaN               NaN
#
#      reply_to_screen_name  is_quote  ...  country_code  place_full_name  \
# 0                     NaN     False  ...           NaN              NaN
# 1                     NaN     False  ...           NaN              NaN
# 2                     NaN     False  ...           NaN              NaN
# 3                     NaN      True  ...           NaN              NaN
# 4                     NaN     False  ...           NaN              NaN
# ...                   ...       ...  ...           ...              ...
# 4995       preferspuppies     False  ...           NaN              NaN
# 4996              dawg_lb     False  ...           NaN              NaN
# 4997                  NaN     False  ...           NaN              NaN
# 4998                  NaN     False  ...           NaN              NaN
# 4999                  NaN     False  ...           NaN              NaN
#
#       place_type followers_count friends_count account_lang  \
# 0            NaN            9094           243          NaN
# 1            NaN           73120         20439          NaN
# 2            NaN           87542         94859          NaN
# 3            NaN           87541         94863          NaN
# 4            NaN           87541         94863          NaN
# ...          ...             ...           ...          ...
# 4995         NaN             725          1064          NaN
# 4996         NaN           46045         46060          NaN
# 4997         NaN            1476           179          NaN
# 4998         NaN            1476           179          NaN
# 4999         NaN            1490          3595          NaN
#
#         account_created_at  verified  lang  \
# 0     2016-10-03T19:40:33Z     False    es
# 1     2009-12-03T15:08:58Z      True    tr
# 2     2013-04-10T09:29:25Z     False    it
# 3     2013-04-10T09:29:25Z     False    it
# 4     2013-04-10T09:29:25Z     False    es
# ...                    ...       ...   ...
# 4995  2009-05-07T18:32:14Z     False    en
# 4996  2009-04-06T16:34:07Z     False    en
# 4997  2017-08-31T14:56:48Z     False    en
# 4998  2017-08-31T14:56:48Z     False    en
# 4999  2013-03-24T16:59:44Z     False    en
#
#                                                   tweet
# 0     "Storms do appreciate\n how “extraordinary was...
# 1                      It is nice...\n 😍😍😍\n"Soul mate"
# 2     In a previous tweet I wrote that Guido Olimpio...
# 3     at full speed #innovation # 3D #Ferrari # covi...
# 4     I hear the debate in #Piazzapulita and it seem...
# ...                                                 ...
# 4995  @preferspuppies @WeTalkSportz @cnnbrk That's t...
# 4996  @dawg_lb It was #CCP &amp; #WHO telling us tha...
# 4997  How well is Delhi prepared to tackle  #covid19...
# 4998  Breaking: Over the past 24 hours, the U.S. rep...
# 4999  So let's just pretend that #Covid_19 isn't a 8...
#
# [5000 rows x 23 columns]

# %% [markdown]
# ### Sentiment Analysis

# %%
# Extract the tweets
tweets30 = data_merge["tweet"]
tweets30.head()
# Out:
# 0    "Storms do appreciate\n how “extraordinary was...
# 1                     It is nice...\n 😍😍😍\n"Soul mate"
# 2    In a previous tweet I wrote that Guido Olimpio...
# 3    at full speed #innovation # 3D #Ferrari # covi...
# 4    I hear the debate in #Piazzapulita and it seem...
# Name: tweet, dtype: object

# %%
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.corpus import twitter_samples, stopwords
from nltk.tag import pos_tag
from nltk.tokenize import word_tokenize
from nltk import FreqDist, classify, NaiveBayesClassifier

import re, string, random

def remove_noise(tweet_tokens, stop_words = ()):

    cleaned_tokens = []

    for token, tag in pos_tag(tweet_tokens):
        token = re.sub('http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+#]|[!*\(\),]|'\
                       '(?:%[0-9a-fA-F][0-9a-fA-F]))+','', token)
        token = re.sub("(@[A-Za-z0-9_]+)","", token)

        if tag.startswith("NN"):
            pos = 'n'
        elif tag.startswith('VB'):
            pos = 'v'
        else:
            pos = 'a'

        lemmatizer = WordNetLemmatizer()
        token = lemmatizer.lemmatize(token, pos)

        if len(token) > 0 and token not in string.punctuation and token.lower() not in stop_words:
            cleaned_tokens.append(token.lower())
    return cleaned_tokens

def get_all_words(cleaned_tokens_list):
    for tokens in cleaned_tokens_list:
        for token in tokens:
            yield token

def get_tweets_for_model(cleaned_tokens_list):
    for tweet_tokens in cleaned_tokens_list:
        yield dict([token, True] for token in tweet_tokens)

if __name__ == "__main__":

    positive_tweets = twitter_samples.strings('positive_tweets.json')
    negative_tweets = twitter_samples.strings('negative_tweets.json')
    text = twitter_samples.strings('tweets.20150430-223406.json')
    tweet_tokens = twitter_samples.tokenized('positive_tweets.json')[0]

    stop_words = stopwords.words('english')

    positive_tweet_tokens = twitter_samples.tokenized('positive_tweets.json')
    negative_tweet_tokens = twitter_samples.tokenized('negative_tweets.json')

    positive_cleaned_tokens_list = []
    negative_cleaned_tokens_list = []

    for tokens in positive_tweet_tokens:
        positive_cleaned_tokens_list.append(remove_noise(tokens, stop_words))

    for tokens in negative_tweet_tokens:
        negative_cleaned_tokens_list.append(remove_noise(tokens, stop_words))

    all_pos_words = get_all_words(positive_cleaned_tokens_list)

    freq_dist_pos = FreqDist(all_pos_words)
    print(freq_dist_pos.most_common(10))

    positive_tokens_for_model = get_tweets_for_model(positive_cleaned_tokens_list)
    negative_tokens_for_model = get_tweets_for_model(negative_cleaned_tokens_list)

    positive_dataset = [(tweet_dict, "Positive")
                         for tweet_dict in positive_tokens_for_model]

    negative_dataset = [(tweet_dict, "Negative")
                         for tweet_dict in negative_tokens_for_model]

    dataset = positive_dataset + negative_dataset

    random.shuffle(dataset)

    train_data = dataset[:7000]
    test_data = dataset[7000:]

    classifier = NaiveBayesClassifier.train(train_data)

    print("Accuracy is:", classify.accuracy(classifier, test_data))

    print(classifier.show_most_informative_features(10))

    custom_tweet = "I ordered just once from TerribleCo, they screwed up, never used the app again."

    custom_tokens = remove_noise(word_tokenize(custom_tweet))

    print(custom_tweet, classifier.classify(dict([token, True] for token in custom_tokens)))
# Out:
# [(':)', 3691), (':-)', 701), (':d', 658), ('thanks', 388), ('follow', 357), ('love', 333), ('...', 290), ('good', 283), ('get', 263), ('thank', 253)]
# Accuracy is: 0.9963333333333333
# Most Informative Features
#                       :( = True           Negati : Positi =   2063.6 : 1.0
#                 follower = True           Positi : Negati =     33.7 : 1.0
#                      sad = True           Negati : Positi =     24.7 : 1.0
#                      bam = True           Positi : Negati =     22.4 : 1.0
#                      x15 = True           Negati : Positi =     17.0 : 1.0
#                community = True           Positi : Negati =     15.0 : 1.0
#                 followed = True           Negati : Positi =     15.0 : 1.0
#                  welcome = True           Positi : Negati =     14.5 : 1.0
#                     damn = True           Negati : Positi =     14.3 : 1.0
#                goodnight = True           Positi : Negati =     13.7 : 1.0
# None
# I ordered just once from TerribleCo, they screwed up, never used the app again. Negative

# %%
from nltk.tokenize import word_tokenize

for tweet in tweets30:
    custom_tokens = remove_noise(word_tokenize(tweet))
    data_merge["polarity"] = classifier.classify(dict([token, True] for token in custom_tokens))

# %%
data_merge.head()
# Out:
#              status_id             user_id            created_at  \
# 0  1250798677796544513  783028986205069312  2020-04-16T14:50:18Z
# 1  1250793907987705856            94346808  2020-04-16T14:31:20Z
# 2  1250802390946676736          1341462944  2020-04-16T15:05:03Z
# 3  1250878232909529094          1341462944  2020-04-16T20:06:25Z
# 4  1250888059756908544          1341462944  2020-04-16T20:45:28Z
#
#        screen_name                                               text  \
# 0  MiguelCalabria3  "Las tormentas hacen apreciar\n lo “extraordin...
# 1       GokhanAkar  Güzel Olmuş...\n 😍😍😍\n"Ruh Eşi"\nhttps://t.co/...
# 2       paoloigna1  In un tweet precedente ho scritto che Guido Ol...
# 3       paoloigna1  a tutta velocità #innovazione #3D #Ferrari #co...
# 4       paoloigna1  Sento il dibattito a #Piazzapulita e sembra ch...
#
#                 source  reply_to_status_id  reply_to_user_id  \
# 0  Twitter for Android                 NaN               NaN
# 1  Twitter for Android                 NaN               NaN
# 2   Twitter Web Client                 NaN               NaN
# 3      Twitter Web App                 NaN               NaN
# 4   Twitter Web Client                 NaN               NaN
#
#   reply_to_screen_name  is_quote  ...  place_full_name  place_type  \
# 0                  NaN     False  ...              NaN         NaN
# 1                  NaN     False  ...              NaN         NaN
# 2                  NaN     False  ...              NaN         NaN
# 3                  NaN      True  ...              NaN         NaN
# 4                  NaN     False  ...              NaN         NaN
#
#    followers_count friends_count account_lang    account_created_at  verified  \
# 0             9094           243          NaN  2016-10-03T19:40:33Z     False
# 1            73120         20439          NaN  2009-12-03T15:08:58Z      True
# 2            87542         94859          NaN  2013-04-10T09:29:25Z     False
# 3            87541         94863          NaN  2013-04-10T09:29:25Z     False
# 4            87541         94863          NaN  2013-04-10T09:29:25Z     False
#
#    lang                                              tweet  polarity
# 0    es  "Storms do appreciate\n how “extraordinary was...  Positive
# 1    tr                   It is nice...\n 😍😍😍\n"Soul mate"  Positive
# 2    it  In a previous tweet I wrote that Guido Olimpio...  Positive
# 3    it  at full speed #innovation # 3D #Ferrari # covi...  Positive
# 4    es  I hear the debate in #Piazzapulita and it seem...  Positive
#
# [5 rows x 24 columns]

# %%
sentiment_data = data_merge[["created_at","tweet","lang","favourites_count","retweet_count","verified","polarity"]]

# %%
sentiment_data.head()
# Out:
#              created_at                                                                                                                                                  tweet lang  favourites_count  \
# 0  2020-04-16T14:50:18Z  "Storms do appreciate\n how “extraordinary was the ordinary”\nAnd they never last forever. "\n-Laura Len #photography\n\n#coronavirus #StayHome #Q...   es           1420056
# 1  2020-04-16T14:31:20Z                                                                                                                       It is nice...\n 😍😍😍\n"Soul mate"   tr           1352326
# 2  2020-04-16T15:05:03Z  In a previous tweet I wrote that Guido Olimpio endorses the hoax, it is not correct and I apologize for it neither confirming nor excluding it. an...   it           1122833
# 3  2020-04-16T20:06:25Z                                                                                         at full speed #innovation # 3D #Ferrari # covid19 #coronavirus   it           1122833
# 4  2020-04-16T20:45:28Z  I hear the debate in #Piazzapulita and it seems that only in #Italy there are problems of chain of command and instead everywhere ... # covid19 Ma...   es           1122833
#
#    retweet_count  verified  polarity
# 0             35     False  Positive
# 1              4      True  Positive
# 2              3     False  Positive
# 3              1     False  Positive
# 4              2     False  Positive

# %%
# save the new data to another CSV file befoe moving to the next stage
sentiment_data.to_csv("Sentiment_30.csv")

# %% [markdown]
# ### Emotion Detection

# %%
from emotion_predictor import EmotionPredictor

# Pandas presentation options
pd.options.display.max_colwidth = 150   # show whole tweet's content
pd.options.display.width = 200          # don't break columns
# Out:
# Using Theano backend.
# WARNING (theano.configdefaults): g++ not detected ! Theano will be unable to execute optimized C-implementations (for both CPU and GPU) and will default to Python implementations. Performance will be severely degraded. To remove this warning, set Theano flags cxx to an empty string.
# WARNING (theano.tensor.blas): Using NumPy C-API based implementation for BLAS functions.

# %%
model = EmotionPredictor(classification='ekman', setting='mc', use_unison_model=True)

# %%
tweets = sentiment_data['tweet'].tolist()

# %%
predictions = model.predict_classes(tweets)

# %%
predictions
# Out:
#                                                                                                                                                      Tweet Emotion
# 0    "Storms do appreciate\n how “extraordinary was the ordinary”\nAnd they never last forever. "\n-Laura Len #photography\n\n#coronavirus #StayHome #Q...     Joy
# 1                                                                                                                         It is nice...\n 😍😍😍\n"Soul mate"     Joy
# 2    In a previous tweet I wrote that Guido Olimpio endorses the hoax, it is not correct and I apologize for it neither confirming nor excluding it. an...     Joy
# 3                                                                                           at full speed #innovation # 3D #Ferrari # covid19 #coronavirus    Fear
# 4    I hear the debate in #Piazzapulita and it seems that only in #Italy there are problems of chain of command and instead everywhere ... # covid19 Ma...     Joy
# ..                                                                                                                                                     ...     ...
# 195                                                                                               @KhaosodEnglish @PravitR # COVID19 #lockdown #Thailand 😷    Fear
# 196                                                                    @GermanyDiplo @HeikoMaas @welt Grand Hotel Sonnenbichl #Bavaria #Germany #COVID19 😷     Joy
# 197                                                                                   @carolinecstark @littlemeanj9 #COVID19 #michiganshutdown #Michigan 😷    Fear
# 198                                                                                          # Covid_19 Anxiety and confinement: what are you doing wrong?    Fear
# 199                                                                                      Ragà what do the infections say compared to yesterday?\n#COVID-19   Anger
#
# [200 rows x 2 columns]

# %%
# Merge predictions with sentiment data

#data_final = pd.concat([sentiment_data.head(200), predictions], axis=1) #the sample
data_final = pd.concat([sentiment_data, predictions], axis=1)
data_final = data_final.drop(['Tweet'], axis=1)


# save the new data to another CSV file befoe moving to the next stage
data_final.to_csv("Emotions.csv")

# %% [markdown]
# 1. Remove links from all tweets. [Done]
# 2. The final dataframe: created at, clean links, polarity, emotion, favourites_count, retweet_count, verified
# 3. Run the model on 2-3 days
# 4. Visulaization
# 5. live stream, see how trends change on time
